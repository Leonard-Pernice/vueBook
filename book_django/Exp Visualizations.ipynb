# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the function with three parameters
def f(x, y, z):
    return np.sin(x) + np.cos(y) + z**2

# Generate the data for the 3D plot
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = f(X, Y, 0.5)

# Create a 3D plot using the surface plot function
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z)

# Set the axis labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Surface Plot')

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the function with three parameters
def f(x, y, z):
    return np.sin(x) + np.cos(y) + z**2

# Generate the data for the 3D plot
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = f(X, Y, 0.5)

# Create a 3D plot using the surface plot function
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap=plt.cm.coolwarm_r)

# Set the axis labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Surface Plot')

# Add a colorbar
fig.colorbar(ax.plot_surface(X, Y, Z), shrink=0.5, aspect=5)

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable

# Define the function with three parameters
def f(x, y, z):
    return np.sin(x) + np.cos(y) + z**2

# Generate the data for the 3D plot
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = f(X, Y, 0.5)

# Scale the values of the function to a range between 0 and 1
norm = Normalize(vmin=Z.min(), vmax=Z.max())
Z_scaled = norm(Z)

# Create a colormap to map the scaled values to colors
cmap = plt.colormaps['RdYlGn']

# Create a 3D plot using the surface plot function
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X, Y, Z, cmap=cmap, norm=norm)

# Add a colorbar
mappable = ScalarMappable(cmap=cmap, norm=norm)
mappable.set_array(Z)
# fig.colorbar(mappable, ax=ax, shrink=0.5, aspect=5)

# Set the axis labels and title
ax.set_xlabel('Amount Spent')
ax.set_ylabel('Amount Remaining')
ax.set_zlabel('Level of Stat/Skill')
ax.set_title('3D Surface Plot')

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable

# Define the function with three parameters
def f(amountSpent, amountLeft, level):
    return 

# Generate the data for the 3D plot
x = np.linspace(0, 100, 100)
y = np.linspace(0, 100, 100)
X, Y = np.meshgrid(x, y)
Z = f(X, Y, 0.5)

# Scale the values of the function to a range between 0 and 1
norm = Normalize(vmin=Z.min(), vmax=Z.max())
Z_scaled = norm(Z)

# Create a colormap to map the scaled values to colors
cmap = plt.colormaps['RdYlGn']

# Create a 3D plot using the surface plot function
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X, Y, Z, cmap=cmap, norm=norm)

# Add a colorbar
mappable = ScalarMappable(cmap=cmap, norm=norm)
mappable.set_array(Z)

# Set the axis labels and title
ax.set_xlabel('Amount Spent')
ax.set_ylabel('Amount Remaining')
ax.set_zlabel('Level of Stat/Skill')
ax.set_title('3D Surface Plot')

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the function to generate the colors of each point
def color_function(x, y, z):
    return np.sin(x) * np.cos(y) + np.exp(z)

# Generate the data for the 3D scatter plot
x = np.random.normal(0, 1, 1000)
y = np.random.normal(0, 1, 1000)
z = np.random.normal(0, 1, 1000)
colors = color_function(x, y, z)

# Create a 3D scatter plot with colored points
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, c=colors, cmap='viridis')

# Set the axis labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Colored Point Cloud')

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


def my_function(spent, level):
    return np.exp(-0.05*level) * (1 - np.exp(-10*spent))

spent_vals = np.linspace(0, 1, 100)
level_vals = np.linspace(1, 100, 100)

spent, level = np.meshgrid(spent_vals, level_vals)
z = my_function(spent, level)

# Create the 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(spent, level, z, cmap='viridis')

# Add labels and title
ax.set_xlabel('Spent')
ax.set_ylabel('Level')
ax.set_zlabel('Result')
ax.set_title('3D Surface Plot')

# Display the plot
plt.show()
